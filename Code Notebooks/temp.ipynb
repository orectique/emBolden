# %%
from rake_nltk import Rake

# %%
with open('../Data/corpus.txt', 'r') as f:
    lines = f.readlines()

lines = [line[:-2] for line in lines]

# %%
corpus = ' '.join(lines)

# %%
r = Rake()

# %%
r.extract_keywords_from_text(corpus)

# %%
r.get_ranked_phrases()
# Out:
# ['two orchard thieves entailed upo us',
#  'never fancied broiling fowls ;-- thoug',
#  'see ?-- posted like silent sentinels',
#  'one char wanting ?-- water --',
#  'coral reefs -- commerce surrounds',
#  'upon suddenly receiving tw handfuls',
#  'years ago -- never mind',
#  'sick -- grow quarrelsome --',
#  'almost every robust healthy boy',
#  'hi deepest reveries -- stand',
#  'old egyptians upon broiled ibis',
#  'deep int distant woodlands winds',
#  'rolled hi island bulk',
#  'pictur lies thus tranced',
#  'philosophical flourish cato throws',
#  'still bette seaward peep',
#  'monied man enter heaven',
#  'stand thousands upon thousands',
#  'discriminating judgment chief among',
#  'belted round b wharves',
#  'archangel gabriel thinks anything',
#  'seated upon th pier',
#  'passengers themselve must pay',
#  'mysterious monster roused al',
#  'sam way -- either',
#  'go fro corlears hook',
#  'one grand hooded phantom',
#  'sigh like leaves upon',
#  'however th old sea',
#  'never pay passengers',
#  'whaling voyage formed part',
#  'deep among tiger',
#  'besides passengers get sea',
#  'tallest boy stand',
#  'every kind whatsoever',
#  'washed b waves',
#  'general thing ;--',
#  'plaster -- tied',
#  'lon precisely --',
#  'avenues -- north',
#  'every one knows',
#  'old persians hold',
#  'old established family',
#  'week days pent',
#  'unde various disguises',
#  'thei huge bake',
#  'th idolatrous dotings',
#  'th great flood',
#  'sleep hi cattle',
#  'robust health soul',
#  'roaste river horse',
#  'pythagorean maxim ),',
#  'mos uncomfortable infliction',
#  'methodically knockin people',
#  'invisible police officer',
#  'honourable respectable toils',
#  'h sadly needed',
#  'green fields gone',
#  'great america desert',
#  'grasp th tormenting',
#  'grand contested election',
#  'dreamy sabbath afternoon',
#  'damp drizzly november',
#  'th bill must',
#  'stand -- miles',
#  'place one lodges',
#  'yonder cottage goes',
#  'world swung open',
#  'thousand patagonian sights',
#  'strong moral principle',
#  'second hand fro',
#  'long time ago',
#  'unaccountable way --',
#  'sail forbidde seas',
#  'earnestly believe money',
#  'better answer tha',
#  'farces -- though',
#  'board -- yet',
#  'without taking care',
#  'captains may order',
#  'lakes take almost',
#  'man receives money',
#  'unless th shepherd',
#  'run something like',
#  'world head winds',
#  'som high aloft',
#  'world betwee paying',
#  'part th commodore',
#  'mortal men fixed',
#  'suc things would',
#  'leaders little suspec',
#  '-- however',
#  'distant seas',
#  'cook ,-- though',
#  'fixed upon',
#  'sea whenever begin',
#  'never violate',
#  'ocea reveries',
#  'grow hazy',
#  'floated int',
#  'ther stand',
#  'never go',
#  'nights --',
#  'lilies --',
#  '-- woul',
#  '-- since',
#  '-- leagues',
#  'old hunks',
#  'old hunks',
#  'ungraspable phantom',
#  'th springs',
#  'th needles',
#  'passed round',
#  'grand programme',
#  'chief element',
#  'besides cajoling',
#  'must needs',
#  'must get',
#  'whaling voyage',
#  'whaling voyage',
#  'whaling voyage',
#  'whaling voyage',
#  'one way',
#  'still deeper',
#  'broiled fowl',
#  'touches one',
#  'one else',
#  'keen one',
#  'yonder warehouses',
#  'would sail',
#  'thousand miles',
#  'tak care',
#  'strong decoction',
#  'rather order',
#  'rag unless',
#  'without falling',
#  'may thump',
#  'high tragedies',
#  'mazy way',
#  'could still',
#  'one ishmael',
#  'wil conceits',
#  'wholesom exercise',
#  'whitehall northward',
#  'whe others',
#  'watery part',
#  'wad knee',
#  'van rensselaers',
#  'urbane activit',
#  'uppe hand',
#  'unpleasant enough',
#  'universal thump',
#  'united states',
#  'unbiased freewill',
#  'tree shakes',
#  'stage managers',
#  'sleepy smoke',
#  'singl penny',
#  'side blue',
#  'shady lee',
#  'shabby part',
#  'separate deity',
#  'seemingly bound',
#  'secretly dogs',
#  'rub eac',
#  'royal mast',
#  'romantic landscape',
#  'rockawa beach',
#  'repeatedly smelt',
#  'really marvellous',
#  'poor poet',
#  'perdition finally',
#  'pedestrian trip',
#  'particula instance',
#  'paid ,--',
#  'pacing straight',
#  'overwhelming idea',
#  'overlapping spurs',
#  'nothin particular',
#  'noble mole',
#  'new testament',
#  'nameless perils',
#  'mystica vibration',
#  'mountains bathed',
#  'metaphysical professor',
#  'mast plumb',
#  'magnificent parts',
#  'magnetic virtue',
#  'judiciously buttered',
#  'judgmatically salted',
#  'jolly parts',
#  'involuntaril pausing',
#  'inmost soul',
#  'infallibly lead',
#  'indignity amount',
#  'indian isles',
#  'hypos get',
#  'honour particularly',
#  'hollow trunk',
#  'ho cheerfully',
#  'growing grim',
#  'greeks give',
#  'get broom',
#  'genteel comedies',
#  'friendly terms',
#  'feelings towards',
#  'extremest limit',
#  'extreme downtown',
#  'extensive performances',
#  'everybody else',
#  'everlasting itch',
#  'endless processions',
#  'enchanting bit',
#  'easy parts',
#  'earthl ills',
#  'dreamiest shadiest',
#  'deliberately stepping',
#  'deliberate whether',
#  'deck gets',
#  'cunningly presented',
#  'constant surveillance',
#  'commonalty lead',
#  'coffin warehouses',
#  'coenties slip',
#  'choice resultin',
#  'castle deck',
#  'caravan happen',
#  'brigs schooners',
#  'brief interlude',
#  'bloody battle',
#  'barbarous coasts',
#  'attending marvels',
#  'without meaning',
#  'may meadow',
#  'first voyage',
#  'sea holy',
#  'quietl take',
#  'especially whenever',
#  'things remote',
#  'high time',
#  'head true',
#  'go visi',
#  'always go',
#  'always go',
#  'ever heard',
#  'ever funeral',
#  'snow hill',
#  'respectfully obey',
#  'pure air',
#  'nothing surprising',
#  'metaphysical point',
#  'insular city',
#  'hours previous',
#  'first told',
#  'considerable glory',
#  'captain orders',
#  'cannot tell',
#  'cannot tell',
#  'high land',
#  'ever go',
#  'ever go',
#  'simple sailor',
#  'merchant sailor',
#  'ships attract',
#  'say reverentially',
#  'mild image',
#  'grea whale',
#  'bu knew',
#  'whenever find',
#  'streets take',
#  '--',
#  'upon',
#  'upon',
#  'winds',
#  'magic stream',
#  'country schoolmaster',
#  'almost',
#  'two',
#  'two',
#  'man',
#  'like',
#  'like',
#  'like',
#  'broiled',
#  'one',
#  'one',
#  'world',
#  'thinks',
#  'leaves',
#  'way',
#  'way',
#  'would',
#  'thing',
#  'tha',
#  'soul',
#  'sleep',
#  'shepherd',
#  'see',
#  'see',
#  'see',
#  'see',
#  'part',
#  'part',
#  'part',
#  'money',
#  'money',
#  'miles',
#  'leaders',
#  'hand',
#  'get',
#  'get',
#  'commodore',
#  'begin',
#  'aloft',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'whenever',
#  'whenever',
#  'take',
#  'take',
#  'things',
#  'things',
#  'head',
#  'head',
#  'go',
#  'go',
#  'go',
#  'go',
#  'go',
#  'al',
#  'al',
#  'al',
#  'yet',
#  'yet',
#  'though',
#  'though',
#  'though',
#  'though',
#  'something',
#  'something',
#  'paying',
#  'paying',
#  'ever',
#  'ever',
#  'cook',
#  'cook',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'time',
#  'time',
#  'time',
#  'time',
#  'tell',
#  'tell',
#  'streets',
#  'stream',
#  'schoolmaster',
#  'respectfully',
#  'previous',
#  'point',
#  'paid',
#  'nothing',
#  'men',
#  'men',
#  'men',
#  'meaning',
#  'meadow',
#  'magic',
#  'little',
#  'little',
#  'little',
#  'ishmael',
#  'hill',
#  'glory',
#  'first',
#  'first',
#  'find',
#  'country',
#  'could',
#  'city',
#  'captain',
#  'air',
#  'sailor',
#  'sailor',
#  'sailor',
#  'whale',
#  'whale',
#  'ships',
#  'ships',
#  'say',
#  'say',
#  'image',
#  'image',
#  'bu',
#  'bu',
#  'land',
#  'land',
#  'land',
#  'land',
#  'land',
#  'yes',
#  'ye',
#  'wonder',
#  'within',
#  'wit',
#  'wish',
#  'wild',
#  'wherefore',
#  'whereas',
#  'wh',
#  'west',
#  'well',
#  'well',
#  'welcome',
#  'weighed',
#  'wedded',
#  'wears',
#  'waterward',
#  'view',
#  'valley',
#  'vain',
#  'unite',
#  'undeliverable',
#  'try',
#  'trouble',
#  'tribulation',
#  'trials',
#  'trees',
#  'travel',
#  'transition',
#  'town',
#  'tormente',
#  'thought',
#  'thither',
#  'think',
#  'thin',
#  'thi',
#  'thence',
#  'tennessee',
#  'ten',
#  'tar',
#  'sword',
#  'sweep',
#  'swayed',
#  'sway',
#  'surf',
#  'surel',
#  'supplie',
#  'suffice',
#  'substitute',
#  'striving',
#  'street',
#  'strange',
#  'story',
#  'stoics',
#  'spleen',
#  'spiles',
#  'speak',
#  'spar',
#  'spar',
#  'south',
#  'sounds',
#  'sort',
#  'sort',
#  'sort',
#  'soo',
#  'somehow',
#  'sol',
#  'social',
#  'sleeps',
#  'slave',
#  'silver',
#  'sight',
#  'sight',
#  'shoulder',
#  'short',
#  'shore',
#  'ship',
#  'ship',
#  'ship',
#  'set',
#  'set',
#  'set',
#  'served',
#  'sense',
#  'seneca',
#  'se',
#  'se',
#  'se',
#  'scores',
#  'scores',
#  'scales',
#  'saw',
#  'satisfaction',
#  'sand',
#  'salt',
#  'sailors',
#  'saco',
#  'root',
#  'rivers',
#  'right',
#  'right',
#  'right',
#  'rigging',
#  'requires',
#  'requires',
#  'regulating',
#  'region',
#  'recall',
#  'reason',
#  'rear',
#  'reaching',
#  'randolphs',
#  'quite',
#  'quietest',
#  'quick',
#  'quarter',
#  'pyramids',
#  'putting',
#  'put',
#  'purse',
#  'purse',
#  'purse',
#  'purpose',
#  'punc',
#  'providence',
#  'promptly',
#  'prevent',
#  'prevalent',
#  'presidency',
#  'prairies',
#  'pot',
#  'possibly',
#  'portentous',
#  'pool',
#  'plunged',
#  'plunged',
#  'please',
#  'pistol',
#  'pine',
#  'physical',
#  'perhaps',
#  'perhaps',
#  'performing',
#  'perceive',
#  'peppered',
#  'path',
#  'passenger',
#  'passenger',
#  'passenger',
#  'passenger',
#  'paint',
#  'offices',
#  'office',
#  'oceans',
#  'ocean',
#  'nig',
#  'niagar',
#  'nearly',
#  'narcissus',
#  'nailed',
#  'mummies',
#  'much',
#  'much',
#  'much',
#  'much',
#  'mouth',
#  'motives',
#  'motives',
#  'minded',
#  'mid',
#  'meet',
#  'meditatio',
#  'mean',
#  'mean',
#  'many',
#  'manhattoes',
#  'making',
#  'make',
#  'make',
#  'lungs',
#  'love',
#  'lording',
#  'looking',
#  'look',
#  'look',
#  'loitering',
#  'life',
#  'let',
#  'let',
#  'less',
#  'legs',
#  'left',
#  'leaning',
#  'lath',
#  'lane',
#  'landsmen',
#  'knowing',
#  'key',
#  'june',
#  'jump',
#  'jove',
#  'invest',
#  'interest',
#  'inmates',
#  'inlanders',
#  'influences',
#  'inferred',
#  'inducements',
#  'induced',
#  'ignoring',
#  'houses',
#  'horror',
#  'hermit',
#  'helped',
#  'heads',
#  'hav',
#  'hats',
#  'hardicanutes',
#  'hands',
#  'habit',
#  'grin',
#  'grasshopper',
#  'good',
#  'going',
#  'going',
#  'going',
#  'going',
#  'gazers',
#  'gates',
#  'fountain',
#  'forecastle',
#  'forecastle',
#  'fore',
#  'feet',
#  'feel',
#  'fates',
#  'fates',
#  'far',
#  'eyes',
#  'eye',
#  'experiment',
#  'exactly',
#  'exactly',
#  'eve',
#  'enjoy',
#  'enable',
#  'employs',
#  'east',
#  'drowned',
#  'drop',
#  'driving',
#  'drawn',
#  'dow',
#  'doubtless',
#  'dive',
#  'distinction',
#  'difference',
#  'di',
#  'desks',
#  'desires',
#  'delusion',
#  'degree',
#  'decks',
#  'dale',
#  'curiosity',
#  'crucifix',
#  'crowds',
#  'crowds',
#  'creatures',
#  'crazy',
#  'counters',
#  'cooled',
#  'contrary',
#  'content',
#  'content',
#  'consign',
#  'considerin',
#  'conscious',
#  'confes',
#  'compasses',
#  'compare',
#  'come',
#  'come',
#  'come',
#  'coat',
#  'clinched',
#  'circumstances',
#  'circumambulate',
#  'circulation',
#  'china',
#  'cheris',
#  'cataract',
#  'carries',
#  'came',
#  'call',
#  'buy',
#  'bulwarks',
#  'brother',
#  'bringing',
#  'breezes',
#  'breathes',
#  'blades',
#  'benches',
#  'bear',
#  'battery',
#  'barques',
#  'ball',
#  'awe',
#  'atmosphere',
#  'athirst',
#  'astern',
#  'assure',
#  'artist',
#  'aroun',
#  'alleys',
#  'ah',
#  'affghanistan',
#  'act',
#  'account',
#  'account',
#  'absent',
#  'abominate',
#  'abandon']
